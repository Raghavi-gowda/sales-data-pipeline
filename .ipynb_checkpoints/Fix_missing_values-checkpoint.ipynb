# %%
import pandas as pd 

df=pd.read_csv('train.csv')
print("missing values\n",df.isnull().sum())
print("\nRaw shape",df.shape)
# Out:
# missing values
#  Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64
#
# Raw shape (9800, 18)

# %%
df['Postal Code']=df['Postal Code'].fillna(0)
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# dtype: int64

# %%
#Fixing datatypes

df['Order Date ']=pd.to_datetime(df['Order Date'],format='%d/%m/%Y')
df['Ship Date'] =pd.to_datetime(df['Ship Date'],format='%d/%m/%Y')


print(df[['Order Date','Ship Date']].dtypes)
# Out:
# Order Date            object
# Ship Date     datetime64[ns]
# dtype: object

# %%
# Convert to datetime
df['Order Date'] = pd.to_datetime(df['Order Date'], format='%d/%m/%Y')

# Now feature engineering works
df['Year'] = df['Order Date'].dt.year
df['Month'] = df['Order Date'].dt.month
df['Quarter'] = 'Q' + df['Order Date'].dt.quarter.astype(str)
df['Ship Days']      = (df['Ship Date'] - df['Order Date']).dt.days

# %%
print(df['Order Date'].dtype)
# Out:
# datetime64[ns]

# %%
# Convert to datetime
df['Order Date'] = pd.to_datetime(df['Order Date'], format='%d/%m/%Y')

# Now feature engineering works
df['Year'] = df['Order Date'].dt.year
df['Month'] = df['Order Date'].dt.month
df['Quarter'] = 'Q' + df['Order Date'].dt.quarter.astype(str)
df['Ship Days']      = (df['Ship Date'] - df['Order Date']).dt.
df['Profit Margin%'] = (df['Profit'] / df['Sales'] * 100).round(2)
